# %%
import pandas as pd

# %%
df1 = pd.read_csv('../raw_data/result.csv')
df1.head()
# Out:
#         allele  seq_num  start  end  length    peptide       core      icore  \
# 0  HLA-A*01:01        1    170  178       9  TSEIQLTDY  TSEIQLTDY  TSEIQLTDY
# 1  HLA-A*02:01        1    424  432       9  SIGGVFTSV  SIGGVFTSV  SIGGVFTSV
# 2  HLA-A*02:01        1    200  208       9  TMKEKSWLV  TMKEKSWLV  TMKEKSWLV
# 3  HLA-A*02:01        1    431  439       9  SVGKLVHQV  SVGKLVHQV  SVGKLVHQV
# 4  HLA-A*01:01        1    124  132       9  KLEGKIVQY  KLEGKIVQY  KLEGKIVQY
#
#       score  rank
# 0  0.933967  0.02
# 1  0.697219  0.13
# 2  0.676498  0.15
# 3  0.630641  0.17
# 4  0.613667  0.13

# %%
df1.shape
# Out:
# (974, 10)

# %%
df2 = pd.read_csv('../raw_data/result (1).csv')
df2.head()
# Out:
#         allele  seq_num  start  end  length    peptide       core      icore  \
# 0  HLA-A*01:01        1    170  178       9  TSEIQLTDY  TSEIQLTDY  TSEIQLTDY
# 1  HLA-A*02:01        1    424  432       9  SIGGVFTSV  SIGGVFTSV  SIGGVFTSV
# 2  HLA-A*02:01        1    200  208       9  TMKEKSWLV  TMKEKSWLV  TMKEKSWLV
# 3  HLA-A*02:01        1    431  439       9  SVGKLVHQV  SVGKLVHQV  SVGKLVHQV
# 4  HLA-A*01:01        1    124  132       9  KLEGKIVQY  KLEGKIVQY  KLEGKIVQY
#
#       score  rank
# 0  0.933967  0.02
# 1  0.697219  0.13
# 2  0.676498  0.15
# 3  0.630641  0.17
# 4  0.613667  0.13

# %%
df2.shape
# Out:
# (974, 10)

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df
# Out:
#            allele  seq_num  start  end  length    peptide       core  \
# 0     HLA-A*01:01        1    170  178       9  TSEIQLTDY  TSEIQLTDY
# 1     HLA-A*02:01        1    424  432       9  SIGGVFTSV  SIGGVFTSV
# 2     HLA-A*02:01        1    200  208       9  TMKEKSWLV  TMKEKSWLV
# 3     HLA-A*02:01        1    431  439       9  SVGKLVHQV  SVGKLVHQV
# 4     HLA-A*01:01        1    124  132       9  KLEGKIVQY  KLEGKIVQY
# ...           ...      ...    ...  ...     ...        ...        ...
# 1943  HLA-A*02:01        1     70   78       9  TDSRCPTQG  TDSRCPTQG
# 1944  HLA-A*02:01        1    336  344       9  PFSTQDEKG  PFSTQDEKG
# 1945  HLA-A*02:01        1    290  298       9  DKLTLKGMS  DKLTLKGMS
# 1946  HLA-A*02:01        1     98  106       9  DRGWGNGCG  DRGWGNGCG
# 1947  HLA-A*02:01        1     92  100       9  CRRTFVDRG  CRRTFVDRG
#
#           icore     score    rank
# 0     TSEIQLTDY  0.933967    0.02
# 1     SIGGVFTSV  0.697219    0.13
# ...

# %%
import seaborn as sns
