# %% [markdown]
# ## MHC-II Dataset Preparation

# %%
import os
import glob
import pandas as pd
# set directory 
os.chdir("../mhc-i/")
# https://www.freecodecamp.org/news/how-to-combine-multiple-csv-files-with-8-lines-of-code-265183e0854/

# %%
# extensions and all files 
extension = 'xlsx'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
print(all_filenames)
# Out:
# ['MN959478.xlsx', 'MN959479.xlsx', 'MT862855.xlsx', 'MN959474.xlsx', 'MT862859.xlsx', 'MN239505.xlsx', 'MN959475.xlsx', 'MN959477.xlsx', 'MT862860.xlsx', 'MN959473.xlsx', 'MN959480.xlsx', 'MT872635.xlsx', 'MT862858.xlsx', ' MN560056.xlsx', 'MN959476.xlsx', 'MT872516.xlsx', 'MN959481.xlsx']

# %%
# combining datasets 
combined_csv = pd.concat([pd.read_excel(f) for f in all_filenames ])

# export to csv: encoding = ‘utf-8-sig’ is added to overcome the issue when exporting ‘Non-English’ languages.
combined_csv.to_csv( "MHC-I.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv("MHC-I.csv")

# %%
df
# Out:
#       accession_code  protein_length  antigen_presenting_protein       allele  \
# 0           MN959478            495.0                      MHC-I  HLA-A*02:01
# 1           MN959478            495.0                      MHC-I  HLA-A*02:01
# 2           MN959478            495.0                      MHC-I  HLA-B*44:02
# 3           MN959478            495.0                      MHC-I  HLA-B*44:02
# 4           MN959478            495.0                      MHC-I  HLA-A*02:01
# ...              ...              ...                        ...          ...
# 15917       MN959481            495.0                      MHC-I  HLA-A*02:01
# 15918       MN959481            495.0                      MHC-I  HLA-A*02:01
# 15919       MN959481            495.0                      MHC-I  HLA-A*02:01
# 15920       MN959481            495.0                      MHC-I  HLA-A*02:01
# 15921       MN959481            495.0                      MHC-I  HLA-A*02:01
#
#        seq_num  start  end  length    peptide       core      icore     score  \
# 0            1    213  221       9  FLDLPLPWL  FLDLPLPWL  FLDLPLPWL  0.882300
# 1            1    346  354       9  HVLGRLITV  HVLGRLITV  HVLGRLITV  0.839721
# 2            1    369  377       9  AEPPFGDSY  AEPPFGDSY  AEPPFGDSY  0.820756
# 3            1     12   20       9  VEGVSGGSW  VEGVSGGSW  VEGVSGGSW  0.776427
# 4            1    431  439       9  SIGKALHQV  SIGKALHQV  SIGKALHQV  0.703158
# ...        ...    ...  ...     ...        ...        ...        ...       ...
# 15917        1    241  249       9  KNPHAKKQD  KNPHAKKQD  KNPHAKKQD  0.000000
# 15918        1    146  154       9  GEEHAVGND  GEEHAVGND  GEEHAVGND  0.000000
# 15919        1     98  106       9  DRGWGNGCG  DRGWGNGCG  DRGWGNGCG  0.000000
# 15920        1     92  100       9  CKHSMVDRG  CKHSMVDRG  CKHSMVDRG  0.000000
# 15921        1     87   95       9  DKRFICKHS  DKRFICKHS  DKRFICKHS  0.000000
#
#          rank acession_code  protein_lenght(AA) antigen_presenting_prortein  \
# 0        0.04           NaN                 NaN                         NaN
# 1        0.06           NaN                 NaN                         NaN
# 2        0.05           NaN                 NaN                         NaN
# 3        0.06           NaN                 NaN                         NaN
# 4        0.13           NaN                 NaN                         NaN
# ...       ...           ...                 ...                         ...
# 15917  100.00           NaN                 NaN                         NaN
# 15918  100.00           NaN                 NaN                         NaN
# 15919  100.00           NaN                 NaN                         NaN
# 15920  100.00           NaN                 NaN                         NaN
# 15921  100.00           NaN                 NaN                         NaN
#
#        protein_length antigen_presenting _protein
# 0                 NaN                         NaN
# 1                 NaN                         NaN
# 2                 NaN                         NaN
# 3                 NaN                         NaN
# 4                 NaN                         NaN
# ...               ...                         ...
# 15917             NaN                         NaN
# 15918             NaN                         NaN
# 15919             NaN                         NaN
# 15920             NaN                         NaN
# 15921             NaN                         NaN
#
# [15922 rows x 18 columns]
